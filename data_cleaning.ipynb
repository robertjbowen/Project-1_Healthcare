# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# import the chicago data file
city_data = pd.read_csv('Data/chicago_data.csv')
city_data
# Out:
#                         date  cases_total  deaths_total  \
# 0    2020-03-29T00:00:00.000          282            20
# 1    2020-03-01T00:00:00.000            0             0
# 2    2020-03-02T00:00:00.000            0             0
# 3    2020-03-03T00:00:00.000            0             0
# 4    2020-03-04T00:00:00.000            0             0
# ..                       ...          ...           ...
# 232  2020-06-04T00:00:00.000          319            14
# 233  2020-07-15T00:00:00.000          267             7
# 234  2020-07-13T00:00:00.000          335             3
# 235  2020-05-14T00:00:00.000          776            45
# 236  2020-10-22T00:00:00.000            2             0
#
#      hospitalizations_total  cases_age_0_17  cases_age_18_29  cases_age_30_39  \
# 0                     130.0               4               29               48
# 1                       2.0               0                0                0
# 2                       2.0               0                0                0
# 3                       3.0               0                0                0
# 4                       4.0               0                0                0
# ..                      ...             ...              ...              ...
# 232                    35.0              27               92               63
# 233                    24.0              30               83               51
# 234                    35.0              36               98               68
# 235                   130.0              49              167              152
# 236                     NaN               0                0                0
#
#      cases_age_40_49  cases_age_50_59  cases_age_60_69  ...  \
# 0                 54               50               50  ...
# 1                  0                0                0  ...
# 2                  0                0                0  ...
# 3                  0                0                0  ...
# 4                  0                0                0  ...
# ..               ...              ...              ...  ...
# 232               54               40               25  ...
# 233               33               34               18  ...
# 234               45               35               31  ...
# 235              132              108               95  ...
# 236                1                0                1  ...
#
#      acute_non_icu_beds_in_use_covid_19  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 232                               721.0
# 233                               423.0
# 234                               361.0
# 235                              1219.0
# 236                               443.0
#
#      acute_non_icu_beds_in_use_covid_19_patients  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 232                                        437.0
# 233                                        184.0
# 234                                        161.0
# 235                                        869.0
# 236                                        226.0
#
#      acute_non_icu_beds_in_use_covid_19_pui  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 232                                   284.0
# 233                                   239.0
# 234                                   200.0
# 235                                   350.0
# 236                                   217.0
#
#      acute_non_icu_beds_in_use_non_covid_19  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 232                                  4593.0
# 233                                  5193.0
# 234                                  5090.0
# 235                                  4824.0
# 236                                  5799.0
#
#      acute_non_icu_beds_available_total  \
# 0                                1638.0
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 232                              2450.0
# 233                              2421.0
# 234                              2592.0
# 235                              1550.0
# 236                              2003.0
#
#      combined_hospital_beds_in_use_covid_19  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 232                                  1033.0
# 233                                   521.0
# 234                                   467.0
# 235                                  1675.0
# 236                                   559.0
#
#                                       daily_update_pdf  \
# 0    {'url': 'https://www.chicago.gov/content/dam/c...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 232  {'url': 'https://www.chicago.gov/content/dam/c...
# 233  {'url': 'https://www.chicago.gov/content/dam/c...
# 234  {'url': 'https://www.chicago.gov/content/dam/c...
# 235  {'url': 'https://www.chicago.gov/content/dam/c...
# 236  {'url': 'https://www.chicago.gov/content/dam/c...
#
#      ventilator_surge_capacity  icu_beds_surge_capacity_adult  \
# 0                        196.0                          218.0
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ..                         ...                            ...
# 232                        NaN                            NaN
# 233                        NaN                            NaN
# 234                        NaN                            NaN
# 235                      312.0                          117.0
# 236                        NaN                            NaN
#
#      icu_beds_surge_capacity_pediatric
# 0                                  8.0
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 232                                NaN
# 233                                NaN
# 234                                NaN
# 235                               20.0
# 236                                NaN
#
# [237 rows x 90 columns]

# %%
# need to format the date column to something usable by matplotlib
# Need to find and replace NaN values with something.... 0?
