# %%
# Import Dependencies
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import datetime

pd.set_option('display.max_rows', 1000)

# %%
#Importing dataset
data_df = pd.read_csv(r"C:\Users\muthukumar\Desktop\005_SaveNWBCSHere\03_Activities&HW\07-git\us-counties\USCounties.csv")

# %%
#Display the dataset
data_df.head()
# Out:
#         date     county       state     fips  cases  deaths
# 0  1/21/2020  Snohomish  Washington  53061.0      1       0
# 1  1/22/2020  Snohomish  Washington  53061.0      1       0
# 2  1/23/2020  Snohomish  Washington  53061.0      1       0
# 3  1/24/2020       Cook    Illinois  17031.0      1       0
# 4  1/24/2020  Snohomish  Washington  53061.0      1       0

# %%
#Cases,Deaths grouped by county
data_grouped = data_df.groupby('state')
data_grouped_df = data_grouped['deaths', 'cases'].sum()
data_grouped_df
# Out:
# <ipython-input-4-4405a78f1c4f>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_grouped_df = data_grouped['deaths', 'cases'].sum()
#                            deaths     cases
# state
# Alabama                    258685  13757084
# Alaska                       4341    672494
# Arizona                    545236  22271168
# Arkansas                   100218   7038898
# California                1603639  77374476
# Colorado                   307374   7999143
# Connecticut                746270   8760794
# Delaware                    88623   2491768
# District of Columbia        95592   2060919
# Florida                   1265202  65213390
# Georgia                    696950  27949474
# Guam                         2868    342737
# Hawaii                       9376    826028
# Idaho                       40229   3467496
# Illinois                  1255840  32987839
# Indiana                    498188  12421667
# Iowa                       150599   8147680
# Kansas                      68315   5165795
# Kentucky                   134194   6004966
# Louisiana                  708691  17975954
# Maine                       20226    653281
# Maryland                   565204  14778904
# Massachusetts             1426483  20355693
# Michigan                  1127430  16490414
# Minnesota                  266838   9473152
# Mississippi                290236   9198127
# Missouri                   231216  10069281
# Montana                     13064    911919
# Nebraska                    55478   4605709
# Nevada                     156334   7346616
# New Hampshire               62302   1110293
# New Jersey                2549308  33009985
# New Mexico                 103325   3157718
# New York                  5777867  77438537
# North Carolina             346798  19349573
# North Dakota                22459   1564723
# Northern Mariana Islands      396      7760
# Ohio                       579986  15175690
# Oklahoma                   105464   6675999
# Oregon                      57861   3043002
# Pennsylvania              1194116  20251638
# Puerto Rico                  2275   3586477
# Rhode Island               159541   3341257
# South Carolina             295163  13110634
# South Dakota                22677   1927803
# Tennessee                  205878  16886089
# Texas                     1306932  67974708
# Utah                        48324   6549422
# Vermont                     10680    257542
# Virgin Islands               1832    106903
# Virginia                   367222  15322485
# Washington                 295045   9689791
# West Virginia               28504   1265626
# Wisconsin                  162963  10620550
# Wyoming                      4996    508430

# %%
data_grouped_c_df = data_grouped_df[data_grouped_df['deaths'] >= 100000].sort_values(by = 'deaths', ascending = False)
data_grouped_f_df = data_grouped_c_df.reset_index()
data_grouped_f_df
# Out:
#              state   deaths     cases
# 0         New York  5777867  77438537
# 1       New Jersey  2549308  33009985
# 2       California  1603639  77374476
# 3    Massachusetts  1426483  20355693
# 4            Texas  1306932  67974708
# 5          Florida  1265202  65213390
# 6         Illinois  1255840  32987839
# 7     Pennsylvania  1194116  20251638
# 8         Michigan  1127430  16490414
# 9      Connecticut   746270   8760794
# 10       Louisiana   708691  17975954
# 11         Georgia   696950  27949474
# 12            Ohio   579986  15175690
# 13        Maryland   565204  14778904
# 14         Arizona   545236  22271168
# 15         Indiana   498188  12421667
# 16        Virginia   367222  15322485
# 17  North Carolina   346798  19349573
# 18        Colorado   307374   7999143
# 19  South Carolina   295163  13110634
# 20      Washington   295045   9689791
# 21     Mississippi   290236   9198127
# 22       Minnesota   266838   9473152
# 23         Alabama   258685  13757084
# 24        Missouri   231216  10069281
# 25       Tennessee   205878  16886089
# 26       Wisconsin   162963  10620550
# 27    Rhode Island   159541   3341257
# 28          Nevada   156334   7346616
# 29            Iowa   150599   8147680
# 30        Kentucky   134194   6004966
# 31        Oklahoma   105464   6675999
# 32      New Mexico   103325   3157718
# 33        Arkansas   100218   7038898

# %%
data_grouped_c_df = data_grouped_f_df[:10]
data_grouped_c_df
# Out:
#            state   deaths     cases
# 0       New York  5777867  77438537
# 1     New Jersey  2549308  33009985
# 2     California  1603639  77374476
# 3  Massachusetts  1426483  20355693
# 4          Texas  1306932  67974708
# 5        Florida  1265202  65213390
# 6       Illinois  1255840  32987839
# 7   Pennsylvania  1194116  20251638
# 8       Michigan  1127430  16490414
# 9    Connecticut   746270   8760794

# %%
#Visualization of Covid deaths vs cases in the top10 affected US counties
states = data_grouped_c_df['state']
dths = data_grouped_c_df['deaths']
css = data_grouped_c_df['cases']

#Create a bar chart based upon the above data 
plt.bar(states, dths, color='b', alpha=0.5, align="center")
#plt.bar(states, css, color='r', alpha=0.5, align="left")
# Create the ticks for our bar chart's x axis 

plt.xticks(states, rotation="vertical")
plt.xlabel('States')
plt.ylabel('CovidDeaths')
plt.title('US State Covid Deaths')
# Out:
# Text(0.5, 1.0, 'US State Covid Deaths')

# %%
#Importing dataset
conf_w_df = pd.read_csv(r"time_series_covid_19_confirmed_PIVOT.csv")
death_w_df = pd.read_csv(r"time_series_covid_19_deaths PIVOT new.csv")
#conf_us_df = pd.read_csv(r"time_series_covid_19_confirmed_US PIVOT.csv")
#death_us_df = pd.read_csv(r"time_series_covid_19_deaths_US PIVOT.csv")
#conf_w_df
#death_w_df
#death_us_df

# %%
conf_w_grouped = conf_w_df.groupby(['Month'])
conf_w_grouped_df = conf_w_grouped.sum()
conf_w_grouped_r_df = conf_w_grouped_df.reset_index()
conf_w_grouped_r_df
# Out:
#    Month  Confirmed Cases           Lat           Long
# 0      1            38536   56063.82050   60726.312140
# 1      2          1672031  162585.07945  176106.305206
# 2      3          9055277  173797.84355  188251.567634
# 3      4         63566010  168191.46150  182178.936420
# 4      5        145046091  173797.84355  188251.567634
# 5      6        246447294  168191.46150  182178.936420
# 6      7        431373538  173797.84355  188251.567634
# 7      8        670846153  173797.84355  188251.567634
# 8      9        661632622  128946.78715  139670.517922

# %%
death_w_grouped = death_w_df.groupby(['Month'])
death_w_grouped_df = death_w_grouped.sum()
death_w_grouped_r_df = death_w_grouped_df.reset_index()
death_w_grouped_r_df
# Out:
#    Month  COVID_DEATHS           Lat           Long
# 0      1           889   56063.82050   60726.312140
# 1      2         46910  162585.07945  176106.305206
# 2      3        398323  173797.84355  188251.567634
# 3      4       4347375  168191.46150  182178.936420
# 4      5       9657801  173797.84355  188251.567634
# 5      6      13294645  168191.46150  182178.936420
# 6      7      18284141  173797.84355  188251.567634
# 7      8      23801937  173797.84355  188251.567634
# 8      9      21117658  128946.78715  139670.517922

# %%
#conf_us_grouped = conf_us_df.groupby(['Month'])
#conf_us_grouped_df = conf_us_grouped.sum()
#conf_us_grouped_r_df = conf_us_grouped_df.reset_index()
#conf_us_grouped_r_df
# Out:
#    Month        Date  CONFIRMED US            UID     code3          FIPS  \
# 0      1  1464807100            41  2786547970180  27872020  1.100954e+09
# 1      2  4249829360           402  8080989113522  80828858  3.192767e+09
# 2      3  4546027240       1117657  8638298707558  86403262  3.412958e+09
# 3      4  4402437300      19691985  8359643910540  83616060  3.302862e+09
# 4      5  4552343180      45413492  8638298707558  86403262  3.412958e+09
# 5      6  4408549500      64816883  8359643910540  83616060  3.302862e+09
# 6      7  4558659120     111045108  8638298707558  86403262  3.412958e+09
# 7      8  4561868860     166134262  8638298707558  86403262  3.412958e+09
# 8      9  3386686520     149311209  6409060331414  64105646  2.532194e+09
#
#             Lat         Long_
# 0  1.226021e+06 -2.959289e+06
# 1  3.555461e+06 -8.581939e+06
# 2  3.800665e+06 -9.173797e+06
# 3  3.678063e+06 -8.877868e+06
# 4  3.800665e+06 -9.173797e+06
# 5  3.678063e+06 -8.877868e+06
# 6  3.800665e+06 -9.173797e+06
# 7  3.800665e+06 -9.173797e+06
# 8  2.819848e+06 -6.806365e+06

# %%
#death_us_grouped = death_us_df.groupby(['Month'])
#death_us_grouped_df = death_us_grouped.sum()
#death_us_grouped_r_df = death_us_grouped_df.reset_index()
#death_us_grouped_r_df
# Out:
#    Month  COVID Death            UID     code3          FIPS           Lat  \
# 0      1           41  2786547970180  27872020  1.100954e+09  1.226021e+06
# 1      2          402  8080989113522  80828858  3.192767e+09  3.555461e+06
# 2      3      1117657  8638298707558  86403262  3.412958e+09  3.800665e+06
# 3      4     19691985  8359643910540  83616060  3.302862e+09  3.678063e+06
# 4      5     45413492  8638298707558  86403262  3.412958e+09  3.800665e+06
# 5      6     64816883  8359643910540  83616060  3.302862e+09  3.678063e+06
# 6      7    111045108  8638298707558  86403262  3.412958e+09  3.800665e+06
# 7      8    166134262  8638298707558  86403262  3.412958e+09  3.800665e+06
# 8      9    149311209  6409060331414  64105646  2.532194e+09  2.819848e+06
#
#           Long_
# 0 -2.959289e+06
# 1 -8.581939e+06
# 2 -9.173797e+06
# 3 -8.877868e+06
# 4 -9.173797e+06
# 5 -8.877868e+06
# 6 -9.173797e+06
# 7 -9.173797e+06
# 8 -6.806365e+06

# %%
M1 = conf_w_grouped_r_df['Month']
M2 = death_w_grouped_r_df['Month']

#M3 = conf_us_grouped_r_df['Month']
#M4 = death_us_grouped_r_df['Month']
a = conf_w_grouped_r_df['Confirmed Cases']
b = death_w_grouped_r_df['COVID_DEATHS']
#e = conf_us_grouped_r_df['CONFIRMED US']
#d = death_us_grouped_r_df['COVID Death']
plt.plot(M1, a, color="red", label="confirmed world cases" )
plt.plot(M2, b, color="green", label="world deaths" )
#plt.plot(M3, e, color="blue", label="confirmed US cases" )
#plt.plot(M4, d, color="pink", label="US deaths" )
plt.ylabel('Case&Death Numbers (mil)')
plt.title('World & US COVID cases and deaths')
plt.legend(loc="best")
plt.grid()
plt.show()
